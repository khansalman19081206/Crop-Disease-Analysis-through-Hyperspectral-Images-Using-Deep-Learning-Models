# %%
# !pip install pennylane
# Out:
# Collecting pennylane
#   Downloading pennylane-0.44.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from pennylane) (1.15.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from pennylane) (3.5)
# Collecting rustworkx>=0.14.0 (from pennylane)
#   Downloading rustworkx-0.17.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: autograd in /usr/local/lib/python3.12/dist-packages (from pennylane) (1.8.0)
# Collecting appdirs (from pennylane)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting autoray==0.8.2 (from pennylane)
#   Downloading autoray-0.8.2-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.12/dist-packages (from pennylane) (5.5.2)
# Collecting pennylane-lightning>=0.44 (from pennylane)
#   Downloading pennylane_lightning-0.44.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from pennylane) (2.32.5)
# Requirement already satisfied: tomlkit in /usr/local/lib/python3.12/dist-packages (from pennylane) (0.13.3)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from pennylane) (4.15.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from pennylane) (26.0rc2)
# Collecting diastatic-malt (from pennylane)
#   Downloading diastatic_malt-2.15.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pennylane) (2.0.2)
# Collecting scipy-openblas32>=0.3.26 (from pennylane-lightning>=0.44->pennylane)
#   Downloading scipy_openblas32-0.3.31.22.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.2/57.2 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: astunparse in /usr/local/lib/python3.12/dist-packages (from diastatic-malt->pennylane) (1.6.3)
# Requirement already satisfied: gast in /usr/local/lib/python3.12/dist-packages (from diastatic-malt->pennylane) (0.6.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from diastatic-malt->pennylane) (3.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->pennylane) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->pennylane) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->pennylane) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->pennylane) (2026.1.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse->diastatic-malt->pennylane) (0.45.1)
# Requirement already satisfied: six<2.0,>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from astunparse->diastatic-malt->pennylane) (1.17.0)
# Downloading pennylane-0.44.0-py3-none-any.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 47.8 MB/s eta 0:00:0000:0100:01
# Downloading autoray-0.8.2-py3-none-any.whl (935 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 935.6/935.6 kB 39.3 MB/s eta 0:00:00
# Downloading pennylane_lightning-0.44.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 61.5 MB/s eta 0:00:00:00:01
# Downloading rustworkx-0.17.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 20.7 MB/s eta 0:00:0000:01m
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading diastatic_malt-2.15.2-py3-none-any.whl (167 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 kB 9.9 MB/s eta 0:00:00
# Downloading scipy_openblas32-0.3.31.22.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 76.7 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: appdirs, scipy-openblas32, rustworkx, autoray, diastatic-malt, pennylane-lightning, pennylane
# Successfully installed appdirs-1.4.4 autoray-0.8.2 diastatic-malt-2.15.2 pennylane-0.44.0 pennylane-lightning-0.44.0 rustworkx-0.17.1 scipy-openblas32-0.3.31.22.1

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import pennylane as qml
from tqdm import tqdm
import math

# %%
# %% [code]
# ===============================
# DATASET + DATALOADERS
# ===============================

import os, glob
import numpy as np
from typing import Tuple
import torch
from torch.utils.data import Dataset, DataLoader

class UAVHSICropDataset(Dataset):
    def __init__(self, root_dir: str, split: str = "Training"):
        if split in ["Training", "Validation"]:
            base = os.path.join(root_dir, split)
        elif split == "Test":
            base = root_dir
        else:
            raise ValueError("split must be Training, Validation or Test")
        self.rs_dir = os.path.join(base, "rs")
        self.gt_dir = os.path.join(base, "gt")
        self.rs_files = sorted(glob.glob(os.path.join(self.rs_dir, "*.npy")))
        self.gt_files = sorted(glob.glob(os.path.join(self.gt_dir, "*.npy")))
        assert len(self.rs_files) == len(self.gt_files), "rs/gt count mismatch"

    def __len__(self):
        return len(self.rs_files)

    def __getitem__(self, idx: int) -> Tuple[torch.Tensor, torch.Tensor]:
        rs = np.load(self.rs_files[idx])
        gt = np.load(self.gt_files[idx])
        rs = torch.from_numpy(rs).float().permute(2,0,1)  # (C,H,W)
        gt = torch.from_numpy(gt).long()                  # (H,W)
        return rs, gt

def make_loaders(root_train, root_test, batch_size=8, num_workers=2):
    train_ds = UAVHSICropDataset(root_train, "Training")
    val_ds   = UAVHSICropDataset(root_train, "Validation")
    test_ds  = UAVHSICropDataset(root_test,  "Test")
    train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True, num_workers=num_workers, pin_memory=True)
    val_loader   = DataLoader(val_ds, batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=True)
    test_loader  = DataLoader(test_ds, batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=True)
    return train_loader, val_loader, test_loader

# %%
# %% [code]
# ===============================
# PATCHGRAPH + HYBRID QUANTUM MODEL
# ===============================

import torch, torch.nn as nn, torch.nn.functional as F
import pennylane as qml
import math

# ---------- Patch Embedding ----------
class PatchEmbed(nn.Module):
    def __init__(self, in_channels=200, patch_size=6, embed_dim=192, img_size=96):
        super().__init__()
        self.grid_h = img_size // patch_size
        self.grid_w = img_size // patch_size
        self.num_patches = self.grid_h * self.grid_w
        self.proj = nn.Conv2d(in_channels, embed_dim, kernel_size=patch_size, stride=patch_size)
        self.pos_embed = nn.Parameter(torch.zeros(1, self.num_patches, embed_dim))

    def forward(self, x):
        x = self.proj(x)
        x = x.flatten(2).transpose(1,2)
        return x + self.pos_embed

# ---------- Grid adjacency ----------
def make_grid_edges(grid_h, grid_w, device):
    N = grid_h * grid_w
    adj = torch.zeros(N,N,device=device)
    def idx(i,j): return i*grid_w+j
    for i in range(grid_h):
        for j in range(grid_w):
            u = idx(i,j)
            for di,dj in [(-1,0),(1,0),(0,-1),(0,1)]:
                ni,nj = i+di, j+dj
                if 0<=ni<grid_h and 0<=nj<grid_w:
                    adj[u, idx(ni,nj)] = 1.0
    adj.fill_diagonal_(1.0)
    adj = adj / adj.sum(1, keepdim=True)
    return adj

# ---------- Graph Attention ----------
class GraphAttention(nn.Module):
    def __init__(self, dim, num_heads=4):
        super().__init__()
        self.num_heads = num_heads
        self.head_dim = dim // num_heads
        self.qkv = nn.Linear(dim, dim*3)
        self.proj = nn.Linear(dim, dim)

    def forward(self, x, adj):
        B,N,D = x.shape
        qkv = self.qkv(x).reshape(B,N,3,self.num_heads,self.head_dim).permute(2,0,3,1,4)
        q,k,v = qkv
        attn = (q @ k.transpose(-2,-1)) / math.sqrt(self.head_dim)
        mask = (adj==0).unsqueeze(0).unsqueeze(0)
        attn = attn.masked_fill(mask, -1e9)
        attn = F.softmax(attn, dim=-1)
        out = attn @ v
        out = out.transpose(1,2).reshape(B,N,D)
        return self.proj(out)

class GraphTransformerBlock(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.norm1 = nn.LayerNorm(dim)
        self.attn = GraphAttention(dim)
        self.norm2 = nn.LayerNorm(dim)
        self.mlp = nn.Sequential(nn.Linear(dim, dim*4), nn.GELU(), nn.Linear(dim*4, dim))

    def forward(self, x, adj):
        x = x + self.attn(self.norm1(x), adj)
        x = x + self.mlp(self.norm2(x))
        return x

# ---------- Classical Head ----------
class ClassicalPatchHead(nn.Module):
    def __init__(self, embed_dim=192, num_classes=30):
        super().__init__()
        self.net = nn.Sequential(nn.Linear(embed_dim, 256), nn.ReLU(), nn.Linear(256, num_classes))
    def forward(self, x):
        return self.net(x)

# ---------- Quantum Global Head ----------
class QuantumGlobalHead(nn.Module):
    def __init__(self, embed_dim=192, num_classes=30, n_qubits=4):
        super().__init__()
        self.reduce = nn.Linear(embed_dim, n_qubits)
        dev = qml.device("default.qubit", wires=n_qubits)
        @qml.qnode(dev, interface="torch")
        def circuit(inputs, weights):
            qml.AngleEmbedding(inputs, wires=range(n_qubits))
            qml.BasicEntanglerLayers(weights, wires=range(n_qubits))
            return [qml.expval(qml.PauliZ(i)) for i in range(n_qubits)]
        self.qlayer = qml.qnn.TorchLayer(circuit, weight_shapes={"weights":(2,n_qubits)})
        self.fc = nn.Linear(n_qubits, num_classes)
    def forward(self, x):
        x = torch.tanh(self.reduce(x))
        x = self.qlayer(x)
        return self.fc(x)

# ---------- Full Hybrid Model ----------
class PatchGraphHybridQuantum(nn.Module):
    def __init__(self, num_classes=30, alpha=0.2, in_channels=200, img_size=96, patch_size=6, embed_dim=192, depth=6):
        super().__init__()
        self.alpha = alpha
        self.patch_embed = PatchEmbed(in_channels, patch_size, embed_dim, img_size)
        Gh = Gw = img_size // patch_size
        self.blocks = nn.ModuleList([GraphTransformerBlock(embed_dim) for _ in range(depth)])
        self.norm = nn.LayerNorm(embed_dim)
        self.classical_head = ClassicalPatchHead(embed_dim, num_classes)
        self.quantum_head = QuantumGlobalHead(embed_dim, num_classes)
        self.Gh, self.Gw = Gh, Gw

    def forward(self, x, output_size):
        device = x.device
        adj = make_grid_edges(self.Gh, self.Gw, device)
        x = self.patch_embed(x)
        for blk in self.blocks:
            x = blk(x, adj)
        x = self.norm(x)
        logits_c = self.classical_head(x)      # (B,N,C)

        global_token = x.mean(dim=1)           # (B,D)
        logits_q = self.quantum_head(global_token)   # (B,C)
        logits_q_exp = logits_q.unsqueeze(1).expand_as(logits_c)
        logits = logits_c + self.alpha*logits_q_exp

        B,N,C = logits.shape
        logits = logits.transpose(1,2).reshape(B,C,self.Gh,self.Gw)
        return F.interpolate(logits,size=output_size,mode="bilinear",align_corners=False)

# %%
# ===============================
# HYBRID CE + LOG-COSH DICE LOSS
# (HSI-TransUNet exact)
# ===============================

import torch
import torch.nn as nn
import torch.nn.functional as F

class HybridCELoss_LogCoshDice(nn.Module):
    def __init__(self, alpha=0.5, eps=1e-5):
        super().__init__()
        self.alpha = alpha
        self.eps = eps
        self.ce = nn.CrossEntropyLoss()

    def forward(self, logits, target):
        """
        logits: (B, C, H, W)
        target: (B, H, W)
        """

        # ----- CE LOSS -----
        ce_loss = self.ce(logits, target)

        # ----- DICE LOSS -----
        num_classes = logits.shape[1]
        probs = torch.softmax(logits, dim=1)          # (B,C,H,W)
        target_oh = F.one_hot(target, num_classes)     # (B,H,W,C)
        target_oh = target_oh.permute(0, 3, 1, 2).float()

        dims = (0, 2, 3)  # batch + spatial
        intersection = torch.sum(probs * target_oh, dims)
        union = torch.sum(probs, dims) + torch.sum(target_oh, dims)

        dice = (2. * intersection + self.eps) / (union + self.eps)
        dice_loss = 1.0 - dice.mean()

        # ----- LOG-COSH DICE -----
        log_cosh_dice = torch.log(torch.cosh(dice_loss))

        # ----- HYBRID -----
        loss = (1 - self.alpha) * ce_loss + self.alpha * log_cosh_dice
        return loss

# %%
# ===============================
# TRAIN / EVAL / METRICS
# ===============================

from sklearn.metrics import confusion_matrix
import numpy as np

def train_one_epoch(model, loader, optimizer, criterion, device):
    model.train()
    total_loss = 0.0

    for rs, gt in loader:
        rs, gt = rs.to(device), gt.to(device)

        optimizer.zero_grad()
        logits = model(rs, gt.shape[-2:])
        loss = criterion(logits, gt)
        loss.backward()
        optimizer.step()

        total_loss += loss.item() * rs.size(0)

    return total_loss / len(loader.dataset)


def eval_one_epoch(model, loader, criterion, device):
    model.eval()
    total_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():
        for rs, gt in loader:
            rs, gt = rs.to(device), gt.to(device)

            logits = model(rs, gt.shape[-2:])
            loss = criterion(logits, gt)
            total_loss += loss.item() * rs.size(0)

            preds = logits.argmax(1)
            correct += (preds == gt).sum().item()
            total += gt.numel()

    return total_loss / len(loader.dataset), correct / total


def compute_confusion_matrix(model, loader, device, num_classes=30):
    model.eval()
    all_preds, all_gts = [], []

    with torch.no_grad():
        for rs, gt in loader:
            rs, gt = rs.to(device), gt.to(device)
            logits = model(rs, gt.shape[-2:])
            preds = logits.argmax(1).cpu().numpy()

            all_preds.extend(preds.ravel())
            all_gts.extend(gt.cpu().numpy().ravel())

    return confusion_matrix(all_gts, all_preds, labels=range(num_classes))


def compute_metrics(cm):
    oa = np.trace(cm) / np.sum(cm)
    aa = np.mean(np.diag(cm) / (cm.sum(1) + 1e-8))
    pe = np.sum(cm.sum(0) * cm.sum(1)) / (np.sum(cm) ** 2)
    kappa = (oa - pe) / (1 - pe + 1e-8)
    miou = np.mean(
        np.diag(cm) / (cm.sum(1) + cm.sum(0) - np.diag(cm) + 1e-8)
    )
    return oa, aa, kappa, miou

# %%
# ===============================
# MAIN TRAINING LOOP
# ===============================

import matplotlib.pyplot as plt
from torch.optim import AdamW

def main():
    root_train = "/kaggle/input/uav-hsi/Train"
    root_test  = "/kaggle/input/uav-hsi/Test"

    train_loader, val_loader, test_loader = make_loaders(
        root_train, root_test, batch_size=8, num_workers=2
    )

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = PatchGraphHybridQuantum(num_classes=30, alpha=0.0).to(device)

    criterion = HybridCELoss_LogCoshDice(alpha=0.5)

    optimizer = AdamW(
        model.parameters(),
        lr=1e-4,
        weight_decay=1e-4
    )

    best_oa = 0.0
    train_losses, val_losses = [], []

    for epoch in range(1, 101):
        train_loss = train_one_epoch(
            model, train_loader, optimizer, criterion, device
        )
        val_loss, val_oa = eval_one_epoch(
            model, val_loader, criterion, device
        )

        train_losses.append(train_loss)
        val_losses.append(val_loss)

        print(
            f"Epoch {epoch:03d} | "
            f"Train Loss: {train_loss:.4f} | "
            f"Val Loss: {val_loss:.4f} | "
            f"Val OA: {val_oa*100:.2f}%"
        )

        if val_oa > best_oa:
            best_oa = val_oa
            torch.save(model.state_dict(), "best_model.pth")
            print("✔ Saved best model (by OA)")

    # ----- TEST -----
    model.load_state_dict(torch.load("best_model.pth", map_location=device))
    test_loss, test_oa = eval_one_epoch(
        model, test_loader, criterion, device
    )

    cm = compute_confusion_matrix(model, test_loader, device)
    oa, aa, kappa, miou = compute_metrics(cm)

    print("\n===== TEST RESULTS =====")
    print(f"Test Loss: {test_loss:.4f}")
    print(f"OA: {oa*100:.2f}%")
    print(f"AA: {aa*100:.2f}%")
    print(f"Kappa: {kappa:.4f}")
    print(f"mIoU: {miou:.4f}")

    plt.figure(figsize=(8,5))
    plt.plot(train_losses, label="Train Loss")
    plt.plot(val_losses, label="Val Loss")
    plt.legend()
    plt.grid()
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# Epoch 001 | Train Loss: 1.2807 | Val Loss: 1.0923 | Val OA: 52.18%
# ✔ Saved best model (by OA)
# Epoch 002 | Train Loss: 0.9811 | Val Loss: 0.9616 | Val OA: 57.83%
# ✔ Saved best model (by OA)
# Epoch 003 | Train Loss: 0.8979 | Val Loss: 0.8849 | Val OA: 58.15%
# ✔ Saved best model (by OA)
# Epoch 004 | Train Loss: 0.8312 | Val Loss: 0.8702 | Val OA: 60.39%
# ✔ Saved best model (by OA)
# Epoch 005 | Train Loss: 0.7961 | Val Loss: 0.8565 | Val OA: 59.04%
# Epoch 006 | Train Loss: 0.7612 | Val Loss: 0.8511 | Val OA: 60.97%
# ✔ Saved best model (by OA)
# Epoch 007 | Train Loss: 0.7396 | Val Loss: 0.7377 | Val OA: 70.18%
# ✔ Saved best model (by OA)
# Epoch 008 | Train Loss: 0.7120 | Val Loss: 0.7423 | Val OA: 69.37%
# Epoch 009 | Train Loss: 0.7275 | Val Loss: 0.7949 | Val OA: 67.34%
# Epoch 010 | Train Loss: 0.6947 | Val Loss: 0.7031 | Val OA: 71.94%
# ✔ Saved best model (by OA)
# Epoch 011 | Train Loss: 0.6588 | Val Loss: 0.7042 | Val OA: 69.70%
# Epoch 012 | Train Loss: 0.6435 | Val Loss: 0.6770 | Val OA: 72.96%
# ✔ Saved best model (by OA)
# Epoch 013 | Train Loss: 0.6197 | Val Loss: 0.6653 | Val OA: 72.39%
# Epoch 014 | Train Loss: 0.6310 | Val Loss: 0.7894 | Val OA: 64.88%
# Epoch 015 | Train Loss: 0.6145 | Val Loss: 0.6498 | Val OA: 72.87%
# Epoch 016 | Train Loss: 0.5840 | Val Loss: 0.6591 | Val OA: 72.87%
# Epoch 017 | Train Loss: 0.5702 | Val Loss: 0.6348 | Val OA: 74.32%
# ✔ Saved best model (by OA)
# Epoch 018 | Train Loss: 0.5970 | Val Loss: 0.6885 | Val OA: 72.38%
# Epoch 019 | Train Loss: 0.5714 | Val Loss: 0.6124 | Val OA: 76.01%
# ✔ Saved best model (by OA)
# Epoch 020 | Train Loss: 0.5755 | Val Loss: 0.6455 | Val OA: 72.08%
# Epoch 021 | Train Loss: 0.5437 | Val Loss: 0.6243 | Val OA: 76.00%
# Epoch 022 | Train Loss: 0.5595 | Val Loss: 0.6051 | Val OA: 75.96%
# Epoch 023 | Train Loss: 0.5392 | Val Loss: 0.6014 | Val OA: 75.73%
# Epoch 024 | Train Loss: 0.5179 | Val Loss: 0.6089 | Val OA: 75.45%
# Epoch 025 | Train Loss: 0.5237 | Val Loss: 0.5767 | Val OA: 77.08%
# ✔ Saved best model (by OA)
# Epoch 026 | Train Loss: 0.5224 | Val Loss: 0.5959 | Val OA: 76.30%
# Epoch 027 | Train Loss: 0.5488 | Val Loss: 0.7342 | Val OA: 67.07%
# Epoch 028 | Train Loss: 0.5669 | Val Loss: 0.6318 | Val OA: 73.14%
# Epoch 029 | Train Loss: 0.5196 | Val Loss: 0.5712 | Val OA: 76.66%
# Epoch 030 | Train Loss: 0.4905 | Val Loss: 0.5476 | Val OA: 78.34%
# ✔ Saved best model (by OA)
# Epoch 031 | Train Loss: 0.4889 | Val Loss: 0.5489 | Val OA: 78.77%
# ✔ Saved best model (by OA)
# Epoch 032 | Train Loss: 0.4687 | Val Loss: 0.5623 | Val OA: 77.02%
# Epoch 033 | Train Loss: 0.4690 | Val Loss: 0.5449 | Val OA: 78.32%
# Epoch 034 | Train Loss: 0.4622 | Val Loss: 0.5705 | Val OA: 75.73%
# Epoch 035 | Train Loss: 0.4505 | Val Loss: 0.5295 | Val OA: 78.10%
# Epoch 036 | Train Loss: 0.4751 | Val Loss: 0.5708 | Val OA: 76.62%
# Epoch 037 | Train Loss: 0.4804 | Val Loss: 0.5356 | Val OA: 78.79%
# ✔ Saved best model (by OA)
# Epoch 038 | Train Loss: 0.4641 | Val Loss: 0.5613 | Val OA: 76.85%
# Epoch 039 | Train Loss: 0.4364 | Val Loss: 0.5223 | Val OA: 79.20%
# ✔ Saved best model (by OA)
# Epoch 040 | Train Loss: 0.4654 | Val Loss: 0.5394 | Val OA: 78.05%
# Epoch 041 | Train Loss: 0.4431 | Val Loss: 0.5313 | Val OA: 78.95%
# Epoch 042 | Train Loss: 0.4202 | Val Loss: 0.5214 | Val OA: 79.10%
# Epoch 043 | Train Loss: 0.4179 | Val Loss: 0.5411 | Val OA: 77.17%
# Epoch 044 | Train Loss: 0.4397 | Val Loss: 0.5157 | Val OA: 78.73%
# Epoch 045 | Train Loss: 0.4327 | Val Loss: 0.4803 | Val OA: 81.30%
# ✔ Saved best model (by OA)
# Epoch 046 | Train Loss: 0.3938 | Val Loss: 0.4631 | Val OA: 82.70%
# ✔ Saved best model (by OA)
# Epoch 047 | Train Loss: 0.3951 | Val Loss: 0.5037 | Val OA: 80.53%
# Epoch 048 | Train Loss: 0.3905 | Val Loss: 0.4705 | Val OA: 82.02%
# Epoch 049 | Train Loss: 0.3878 | Val Loss: 0.4889 | Val OA: 81.08%
# Epoch 050 | Train Loss: 0.4143 | Val Loss: 0.5694 | Val OA: 75.84%
# Epoch 051 | Train Loss: 0.3875 | Val Loss: 0.4662 | Val OA: 82.10%
# Epoch 052 | Train Loss: 0.3620 | Val Loss: 0.4634 | Val OA: 82.47%
# Epoch 053 | Train Loss: 0.3807 | Val Loss: 0.4682 | Val OA: 82.43%
# Epoch 054 | Train Loss: 0.3542 | Val Loss: 0.4990 | Val OA: 80.70%
# Epoch 055 | Train Loss: 0.3666 | Val Loss: 0.4514 | Val OA: 83.15%
# ✔ Saved best model (by OA)
# Epoch 056 | Train Loss: 0.3383 | Val Loss: 0.4691 | Val OA: 82.30%
# Epoch 057 | Train Loss: 0.3446 | Val Loss: 0.4468 | Val OA: 83.37%
# ✔ Saved best model (by OA)
# Epoch 058 | Train Loss: 0.3408 | Val Loss: 0.4490 | Val OA: 82.15%
# Epoch 059 | Train Loss: 0.3360 | Val Loss: 0.4299 | Val OA: 84.03%
# ✔ Saved best model (by OA)
# Epoch 060 | Train Loss: 0.3262 | Val Loss: 0.4426 | Val OA: 83.19%
# Epoch 061 | Train Loss: 0.3169 | Val Loss: 0.4333 | Val OA: 84.49%
# ✔ Saved best model (by OA)
# Epoch 062 | Train Loss: 0.3074 | Val Loss: 0.4196 | Val OA: 85.25%
# ✔ Saved best model (by OA)
# Epoch 063 | Train Loss: 0.3109 | Val Loss: 0.4874 | Val OA: 79.70%
# Epoch 064 | Train Loss: 0.3728 | Val Loss: 0.4646 | Val OA: 81.30%
# Epoch 065 | Train Loss: 0.3843 | Val Loss: 0.5185 | Val OA: 80.53%
# Epoch 066 | Train Loss: 0.3957 | Val Loss: 0.5028 | Val OA: 77.87%
# Epoch 067 | Train Loss: 0.3344 | Val Loss: 0.4330 | Val OA: 83.77%
# Epoch 068 | Train Loss: 0.2939 | Val Loss: 0.4425 | Val OA: 83.77%
# Epoch 069 | Train Loss: 0.2957 | Val Loss: 0.4491 | Val OA: 81.97%
# Epoch 070 | Train Loss: 0.2896 | Val Loss: 0.4336 | Val OA: 83.57%
# Epoch 071 | Train Loss: 0.3018 | Val Loss: 0.4827 | Val OA: 81.35%
# Epoch 072 | Train Loss: 0.2770 | Val Loss: 0.4078 | Val OA: 84.83%
# Epoch 073 | Train Loss: 0.2729 | Val Loss: 0.4194 | Val OA: 83.86%
# Epoch 074 | Train Loss: 0.2556 | Val Loss: 0.4098 | Val OA: 85.42%
# ✔ Saved best model (by OA)
# Epoch 075 | Train Loss: 0.2514 | Val Loss: 0.4036 | Val OA: 84.96%
# Epoch 076 | Train Loss: 0.2464 | Val Loss: 0.4119 | Val OA: 84.80%
# Epoch 077 | Train Loss: 0.2399 | Val Loss: 0.4324 | Val OA: 83.75%
# Epoch 078 | Train Loss: 0.2326 | Val Loss: 0.4082 | Val OA: 85.21%
# Epoch 079 | Train Loss: 0.2337 | Val Loss: 0.4336 | Val OA: 83.34%
# Epoch 080 | Train Loss: 0.2394 | Val Loss: 0.4488 | Val OA: 83.50%
# Epoch 081 | Train Loss: 0.2283 | Val Loss: 0.4105 | Val OA: 85.03%
# Epoch 082 | Train Loss: 0.2175 | Val Loss: 0.4152 | Val OA: 84.06%
# Epoch 083 | Train Loss: 0.2170 | Val Loss: 0.4202 | Val OA: 84.37%
# Epoch 084 | Train Loss: 0.2108 | Val Loss: 0.4197 | Val OA: 84.81%
# Epoch 085 | Train Loss: 0.2160 | Val Loss: 0.4142 | Val OA: 85.23%
# Epoch 086 | Train Loss: 0.2091 | Val Loss: 0.3995 | Val OA: 85.36%
# Epoch 087 | Train Loss: 0.2239 | Val Loss: 0.4272 | Val OA: 83.88%
# Epoch 088 | Train Loss: 0.2166 | Val Loss: 0.4154 | Val OA: 84.43%
# Epoch 089 | Train Loss: 0.1979 | Val Loss: 0.4088 | Val OA: 84.38%
# Epoch 090 | Train Loss: 0.1906 | Val Loss: 0.4059 | Val OA: 85.36%
# Epoch 091 | Train Loss: 0.1948 | Val Loss: 0.4861 | Val OA: 81.73%
# Epoch 092 | Train Loss: 0.2528 | Val Loss: 0.4547 | Val OA: 82.81%
# Epoch 093 | Train Loss: 0.2086 | Val Loss: 0.4475 | Val OA: 84.10%
# Epoch 094 | Train Loss: 0.1895 | Val Loss: 0.4439 | Val OA: 83.87%
# Epoch 095 | Train Loss: 0.1784 | Val Loss: 0.4172 | Val OA: 85.38%
# Epoch 096 | Train Loss: 0.1734 | Val Loss: 0.4300 | Val OA: 84.94%
# Epoch 097 | Train Loss: 0.1709 | Val Loss: 0.4273 | Val OA: 84.96%
# Epoch 098 | Train Loss: 0.1679 | Val Loss: 0.4313 | Val OA: 84.12%
# Epoch 099 | Train Loss: 0.1703 | Val Loss: 0.4773 | Val OA: 84.12%
# Epoch 100 | Train Loss: 0.1692 | Val Loss: 0.4269 | Val OA: 85.12%
#
# ===== TEST RESULTS =====
# Test Loss: 0.4974
# OA: 81.92%
# AA: 34.11%
# Kappa: 0.7841
# mIoU: 0.2795
