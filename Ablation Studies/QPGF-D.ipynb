# %%
# !pip install pennylane
# Out:
# Collecting pennylane
#   Downloading pennylane-0.44.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from pennylane) (1.15.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from pennylane) (3.5)
# Collecting rustworkx>=0.14.0 (from pennylane)
#   Downloading rustworkx-0.17.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: autograd in /usr/local/lib/python3.12/dist-packages (from pennylane) (1.8.0)
# Collecting appdirs (from pennylane)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting autoray==0.8.2 (from pennylane)
#   Downloading autoray-0.8.2-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.12/dist-packages (from pennylane) (5.5.2)
# Collecting pennylane-lightning>=0.44 (from pennylane)
#   Downloading pennylane_lightning-0.44.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from pennylane) (2.32.5)
# Requirement already satisfied: tomlkit in /usr/local/lib/python3.12/dist-packages (from pennylane) (0.13.3)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from pennylane) (4.15.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from pennylane) (26.0rc2)
# Collecting diastatic-malt (from pennylane)
#   Downloading diastatic_malt-2.15.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pennylane) (2.0.2)
# Collecting scipy-openblas32>=0.3.26 (from pennylane-lightning>=0.44->pennylane)
#   Downloading scipy_openblas32-0.3.31.22.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.2/57.2 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: astunparse in /usr/local/lib/python3.12/dist-packages (from diastatic-malt->pennylane) (1.6.3)
# Requirement already satisfied: gast in /usr/local/lib/python3.12/dist-packages (from diastatic-malt->pennylane) (0.6.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from diastatic-malt->pennylane) (3.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->pennylane) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->pennylane) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->pennylane) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->pennylane) (2026.1.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse->diastatic-malt->pennylane) (0.45.1)
# Requirement already satisfied: six<2.0,>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from astunparse->diastatic-malt->pennylane) (1.17.0)
# Downloading pennylane-0.44.0-py3-none-any.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 27.9 MB/s eta 0:00:0000:0100:01
# Downloading autoray-0.8.2-py3-none-any.whl (935 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 935.6/935.6 kB 43.8 MB/s eta 0:00:00
# Downloading pennylane_lightning-0.44.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 62.3 MB/s eta 0:00:00:00:01
# Downloading rustworkx-0.17.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 40.4 MB/s eta 0:00:0000:01
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading diastatic_malt-2.15.2-py3-none-any.whl (167 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 kB 10.4 MB/s eta 0:00:00
# Downloading scipy_openblas32-0.3.31.22.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 85.3 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: appdirs, scipy-openblas32, rustworkx, autoray, diastatic-malt, pennylane-lightning, pennylane
# Successfully installed appdirs-1.4.4 autoray-0.8.2 diastatic-malt-2.15.2 pennylane-0.44.0 pennylane-lightning-0.44.0 rustworkx-0.17.1 scipy-openblas32-0.3.31.22.1

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import pennylane as qml
from tqdm import tqdm
import math

# %%
# %% [code]
# ===============================
# DATASET + DATALOADERS
# ===============================

import os, glob
import numpy as np
from typing import Tuple
import torch
from torch.utils.data import Dataset, DataLoader

class UAVHSICropDataset(Dataset):
    def __init__(self, root_dir: str, split: str = "Training"):
        if split in ["Training", "Validation"]:
            base = os.path.join(root_dir, split)
        elif split == "Test":
            base = root_dir
        else:
            raise ValueError("split must be Training, Validation or Test")
        self.rs_dir = os.path.join(base, "rs")
        self.gt_dir = os.path.join(base, "gt")
        self.rs_files = sorted(glob.glob(os.path.join(self.rs_dir, "*.npy")))
        self.gt_files = sorted(glob.glob(os.path.join(self.gt_dir, "*.npy")))
        assert len(self.rs_files) == len(self.gt_files), "rs/gt count mismatch"

    def __len__(self):
        return len(self.rs_files)

    def __getitem__(self, idx: int) -> Tuple[torch.Tensor, torch.Tensor]:
        rs = np.load(self.rs_files[idx])
        gt = np.load(self.gt_files[idx])
        rs = torch.from_numpy(rs).float().permute(2,0,1)  # (C,H,W)
        gt = torch.from_numpy(gt).long()                  # (H,W)
        return rs, gt

def make_loaders(root_train, root_test, batch_size=8, num_workers=2):
    train_ds = UAVHSICropDataset(root_train, "Training")
    val_ds   = UAVHSICropDataset(root_train, "Validation")
    test_ds  = UAVHSICropDataset(root_test,  "Test")
    train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True, num_workers=num_workers, pin_memory=True)
    val_loader   = DataLoader(val_ds, batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=True)
    test_loader  = DataLoader(test_ds, batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=True)
    return train_loader, val_loader, test_loader

# %%
# %% [code]
# ===============================
# PATCHGRAPH + HYBRID QUANTUM MODEL
# ===============================

import torch, torch.nn as nn, torch.nn.functional as F
import pennylane as qml
import math

# ---------- Patch Embedding ----------
class PatchEmbed(nn.Module):
    def __init__(self, in_channels=200, patch_size=6, embed_dim=192, img_size=96):
        super().__init__()
        self.grid_h = img_size // patch_size
        self.grid_w = img_size // patch_size
        self.num_patches = self.grid_h * self.grid_w
        self.proj = nn.Conv2d(in_channels, embed_dim, kernel_size=patch_size, stride=patch_size)
        self.pos_embed = nn.Parameter(torch.zeros(1, self.num_patches, embed_dim))

    def forward(self, x):
        x = self.proj(x)
        x = x.flatten(2).transpose(1,2)
        return x + self.pos_embed

# ---------- Grid adjacency ----------
def make_grid_edges(grid_h, grid_w, device):
    N = grid_h * grid_w
    adj = torch.zeros(N,N,device=device)
    def idx(i,j): return i*grid_w+j
    for i in range(grid_h):
        for j in range(grid_w):
            u = idx(i,j)
            for di,dj in [(-1,0),(1,0),(0,-1),(0,1)]:
                ni,nj = i+di, j+dj
                if 0<=ni<grid_h and 0<=nj<grid_w:
                    adj[u, idx(ni,nj)] = 1.0
    adj.fill_diagonal_(1.0)
    adj = adj / adj.sum(1, keepdim=True)
    return adj

# ---------- Graph Attention ----------
class GraphAttention(nn.Module):
    def __init__(self, dim, num_heads=4):
        super().__init__()
        self.num_heads = num_heads
        self.head_dim = dim // num_heads
        self.qkv = nn.Linear(dim, dim*3)
        self.proj = nn.Linear(dim, dim)

    def forward(self, x, adj):
        B,N,D = x.shape
        qkv = self.qkv(x).reshape(B,N,3,self.num_heads,self.head_dim).permute(2,0,3,1,4)
        q,k,v = qkv
        attn = (q @ k.transpose(-2,-1)) / math.sqrt(self.head_dim)
        mask = (adj==0).unsqueeze(0).unsqueeze(0)
        attn = attn.masked_fill(mask, -1e9)
        attn = F.softmax(attn, dim=-1)
        out = attn @ v
        out = out.transpose(1,2).reshape(B,N,D)
        return self.proj(out)

class GraphTransformerBlock(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.norm1 = nn.LayerNorm(dim)
        self.attn = GraphAttention(dim)
        self.norm2 = nn.LayerNorm(dim)
        self.mlp = nn.Sequential(nn.Linear(dim, dim*4), nn.GELU(), nn.Linear(dim*4, dim))

    def forward(self, x, adj):
        x = x + self.attn(self.norm1(x), adj)
        x = x + self.mlp(self.norm2(x))
        return x

# ---------- Classical Head ----------
class ClassicalPatchHead(nn.Module):
    def __init__(self, embed_dim=192, num_classes=30):
        super().__init__()
        self.net = nn.Sequential(nn.Linear(embed_dim, 256), nn.ReLU(), nn.Linear(256, num_classes))
    def forward(self, x):
        return self.net(x)

# ---------- Quantum Global Head ----------
class QuantumGlobalHead(nn.Module):
    def __init__(self, embed_dim=192, num_classes=30, n_qubits=4):
        super().__init__()
        self.reduce = nn.Linear(embed_dim, n_qubits)
        dev = qml.device("default.qubit", wires=n_qubits)
        @qml.qnode(dev, interface="torch")
        def circuit(inputs, weights):
            qml.AngleEmbedding(inputs, wires=range(n_qubits))
            qml.BasicEntanglerLayers(weights, wires=range(n_qubits))
            return [qml.expval(qml.PauliZ(i)) for i in range(n_qubits)]
        self.qlayer = qml.qnn.TorchLayer(circuit, weight_shapes={"weights":(2,n_qubits)})
        self.fc = nn.Linear(n_qubits, num_classes)
    def forward(self, x):
        x = torch.tanh(self.reduce(x))
        x = self.qlayer(x)
        return self.fc(x)

# ---------- Full Hybrid Model ----------
class PatchGraphHybridQuantum(nn.Module):
    def __init__(self, num_classes=30, alpha=0.2, in_channels=200, img_size=96, patch_size=6, embed_dim=192, depth=6):
        super().__init__()
        self.alpha = alpha
        self.patch_embed = PatchEmbed(in_channels, patch_size, embed_dim, img_size)
        Gh = Gw = img_size // patch_size
        self.blocks = nn.ModuleList([GraphTransformerBlock(embed_dim) for _ in range(depth)])
        self.norm = nn.LayerNorm(embed_dim)
        self.classical_head = ClassicalPatchHead(embed_dim, num_classes)
        self.quantum_head = QuantumGlobalHead(embed_dim, num_classes)
        self.Gh, self.Gw = Gh, Gw

    def forward(self, x, output_size):
        device = x.device
        adj = make_grid_edges(self.Gh, self.Gw, device)
        x = self.patch_embed(x)
        for blk in self.blocks:
            x = blk(x, adj)
        x = self.norm(x)
        logits_c = self.classical_head(x)      # (B,N,C)

        global_token = x.mean(dim=1)           # (B,D)
        logits_q = self.quantum_head(global_token)   # (B,C)
        logits_q_exp = logits_q.unsqueeze(1).expand_as(logits_c)
        logits = logits_c + self.alpha*logits_q_exp

        B,N,C = logits.shape
        logits = logits.transpose(1,2).reshape(B,C,self.Gh,self.Gw)
        return F.interpolate(logits,size=output_size,mode="bilinear",align_corners=False)

# %%
# %% [code]
# ===============================
# TRAINING / EVAL / METRICS
# ===============================

import torch
from torch.optim import AdamW
import torch.nn.functional as F
from sklearn.metrics import confusion_matrix
import numpy as np

def train_one_epoch(model, loader, optimizer, criterion, device, alpha=0.2):
    model.train()
    model.alpha = alpha
    total_loss = 0
    for rs, gt in loader:
        rs, gt = rs.to(device), gt.to(device)
        optimizer.zero_grad()
        logits = model(rs, gt.shape[-2:])
        loss = criterion(logits, gt)
        loss.backward()
        optimizer.step()
        total_loss += loss.item() * rs.size(0)
    return total_loss / len(loader.dataset)

def eval_one_epoch(model, loader, criterion, device):
    model.eval()
    total_loss, correct, total = 0,0,0
    with torch.no_grad():
        for rs, gt in loader:
            rs, gt = rs.to(device), gt.to(device)
            logits = model(rs, gt.shape[-2:])
            loss = criterion(logits, gt)
            total_loss += loss.item() * rs.size(0)
            preds = logits.argmax(1)
            correct += (preds==gt).sum().item()
            total += gt.numel()
    return total_loss / len(loader.dataset), correct/total

def compute_confusion_matrix(model, loader, device, num_classes=30):
    model.eval()
    all_preds, all_gts = [], []
    with torch.no_grad():
        for rs, gt in loader:
            rs, gt = rs.to(device), gt.to(device)
            logits = model(rs, gt.shape[-2:])
            preds = logits.argmax(1).cpu().numpy()
            all_preds.extend(preds.ravel())
            all_gts.extend(gt.cpu().numpy().ravel())
    cm = confusion_matrix(all_gts, all_preds, labels=range(num_classes))
    return cm

def compute_metrics(cm):
    oa = np.trace(cm)/np.sum(cm)
    aa = np.mean(np.diag(cm)/(cm.sum(1)+1e-8))
    pe = np.sum(cm.sum(0)*cm.sum(1))/np.sum(cm)**2
    kappa = (oa-pe)/(1-pe+1e-8)
    miou = np.mean(np.diag(cm)/(cm.sum(1)+cm.sum(0)-np.diag(cm)+1e-8))
    return oa, aa, kappa, miou

# %%
# %% [code]
# ===============================
# MAIN TRAINING LOOP
# ===============================

import matplotlib.pyplot as plt

def main():
    root_train = "/kaggle/input/uav-hsi/Train"
    root_test  = "/kaggle/input/uav-hsi/Test"

    train_loader, val_loader, test_loader = make_loaders(root_train, root_test, batch_size=8, num_workers=2)

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = PatchGraphHybridQuantum(num_classes=30, alpha=0.0).to(device)

    # Compute class weights from training GT
    all_gts = []
    for _, gt in train_loader:
        all_gts.append(gt.numpy().ravel())
    all_gts = np.concatenate(all_gts)
    class_counts = np.bincount(all_gts, minlength=30)
    class_weights = 1.0 / (class_counts + 1e-8)
    class_weights = 1.0 / np.sqrt(class_counts + 1e-6)
    class_weights = torch.tensor(class_weights, device=device, dtype=torch.float32)
    criterion = nn.CrossEntropyLoss(weight=class_weights)

    optimizer = AdamW([
        {"params": model.patch_embed.parameters()},
        {"params": model.blocks.parameters()},
        {"params": model.classical_head.parameters()},
        {"params": model.quantum_head.parameters(), "lr": 5e-5},
    ], lr=3e-4, weight_decay=1e-4)

    best_val = float("inf")
    train_losses, val_losses, val_oa_list = [],[],[]

    for epoch in range(1, 101):
        alpha = min(0.2, epoch/30*0.2)  # alpha schedule
        print(f"\nEpoch {epoch} | alpha={alpha:.3f}")

        train_loss = train_one_epoch(model, train_loader, optimizer, criterion, device, alpha)
        val_loss, val_oa = eval_one_epoch(model, val_loader, criterion, device)

        train_losses.append(train_loss)
        val_losses.append(val_loss)
        val_oa_list.append(val_oa)

        print(f"Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f} | Val OA: {val_oa*100:.2f}%")
        if val_loss < best_val:
            best_val = val_loss
            torch.save(model.state_dict(), "patchgraph_hybrid_quantum_best.pth")
            print("Saved best model.")

    # final evaluation
    model.load_state_dict(torch.load("patchgraph_hybrid_quantum_best.pth", map_location=device))
    test_loss, test_oa = eval_one_epoch(model, test_loader, criterion, device)
    print(f"\nTest Loss: {test_loss:.4f} | Test OA: {test_oa*100:.2f}%")

    cm = compute_confusion_matrix(model, test_loader, device)
    oa, aa, kappa, miou = compute_metrics(cm)
    print(f"OA: {oa*100:.2f}%, AA: {aa*100:.2f}%, Kappa: {kappa:.4f}, mIoU: {miou:.4f}")

    # plot train/val curve
    plt.figure(figsize=(8,5))
    plt.plot(train_losses, label="Train Loss")
    plt.plot(val_losses, label="Val Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title("Training/Validation Loss")
    plt.legend()
    plt.show()

if __name__=="__main__":
    main()
# Out:
# Epoch 1 | alpha=0.007
# Train Loss: 2.6948 | Val Loss: 2.5657 | Val OA: 55.07%
# Saved best model.
#
# Epoch 2 | alpha=0.013
# Train Loss: 2.2626 | Val Loss: 2.3916 | Val OA: 54.42%
# Saved best model.
#
# Epoch 3 | alpha=0.020
# Train Loss: 2.0781 | Val Loss: 2.1676 | Val OA: 63.82%
# Saved best model.
#
# Epoch 4 | alpha=0.027
# Train Loss: 1.9541 | Val Loss: 2.2050 | Val OA: 59.88%
#
# Epoch 5 | alpha=0.033
# Train Loss: 1.8692 | Val Loss: 2.0212 | Val OA: 64.02%
# Saved best model.
#
# Epoch 6 | alpha=0.040
# Train Loss: 1.8215 | Val Loss: 2.0228 | Val OA: 59.25%
#
# Epoch 7 | alpha=0.047
# Train Loss: 1.7549 | Val Loss: 1.9664 | Val OA: 62.35%
# Saved best model.
#
# Epoch 8 | alpha=0.053
# Train Loss: 1.7542 | Val Loss: 2.2922 | Val OA: 50.01%
#
# Epoch 9 | alpha=0.060
# Train Loss: 1.8021 | Val Loss: 1.8240 | Val OA: 65.11%
# Saved best model.
#
# Epoch 10 | alpha=0.067
# Train Loss: 1.6670 | Val Loss: 1.7644 | Val OA: 65.20%
# Saved best model.
#
# Epoch 11 | alpha=0.073
# Train Loss: 1.6043 | Val Loss: 1.7187 | Val OA: 65.68%
# Saved best model.
#
# Epoch 12 | alpha=0.080
# Train Loss: 1.5525 | Val Loss: 1.6776 | Val OA: 68.22%
# Saved best model.
#
# Epoch 13 | alpha=0.087
# Train Loss: 1.5127 | Val Loss: 1.8210 | Val OA: 62.38%
#
# Epoch 14 | alpha=0.093
# Train Loss: 1.5651 | Val Loss: 1.7585 | Val OA: 63.85%
#
# Epoch 15 | alpha=0.100
# Train Loss: 1.4826 | Val Loss: 1.6140 | Val OA: 67.57%
# Saved best model.
#
# Epoch 16 | alpha=0.107
# Train Loss: 1.4114 | Val Loss: 1.6449 | Val OA: 67.66%
#
# Epoch 17 | alpha=0.113
# Train Loss: 1.4044 | Val Loss: 1.5940 | Val OA: 65.74%
# Saved best model.
#
# Epoch 18 | alpha=0.120
# Train Loss: 1.4702 | Val Loss: 1.7787 | Val OA: 60.03%
#
# Epoch 19 | alpha=0.127
# Train Loss: 1.4707 | Val Loss: 1.5443 | Val OA: 68.45%
# Saved best model.
#
# Epoch 20 | alpha=0.133
# Train Loss: 1.3683 | Val Loss: 1.5347 | Val OA: 65.62%
# Saved best model.
#
# Epoch 21 | alpha=0.140
# Train Loss: 1.3376 | Val Loss: 1.6070 | Val OA: 66.19%
#
# Epoch 22 | alpha=0.147
# Train Loss: 1.3279 | Val Loss: 1.4705 | Val OA: 67.78%
# Saved best model.
#
# Epoch 23 | alpha=0.153
# Train Loss: 1.3413 | Val Loss: 1.5247 | Val OA: 69.95%
#
# Epoch 24 | alpha=0.160
# Train Loss: 1.2740 | Val Loss: 1.4622 | Val OA: 70.07%
# Saved best model.
#
# Epoch 25 | alpha=0.167
# Train Loss: 1.2264 | Val Loss: 1.4744 | Val OA: 70.64%
#
# Epoch 26 | alpha=0.173
# Train Loss: 1.2944 | Val Loss: 1.5053 | Val OA: 65.09%
#
# Epoch 27 | alpha=0.180
# Train Loss: 1.2775 | Val Loss: 1.4677 | Val OA: 65.25%
#
# Epoch 28 | alpha=0.187
# Train Loss: 1.2226 | Val Loss: 1.4761 | Val OA: 69.79%
#
# Epoch 29 | alpha=0.193
# Train Loss: 1.1488 | Val Loss: 1.4010 | Val OA: 70.52%
# Saved best model.
#
# Epoch 30 | alpha=0.200
# Train Loss: 1.1184 | Val Loss: 1.3719 | Val OA: 68.97%
# Saved best model.
#
# Epoch 31 | alpha=0.200
# Train Loss: 1.0626 | Val Loss: 1.3362 | Val OA: 69.70%
# Saved best model.
#
# Epoch 32 | alpha=0.200
# Train Loss: 1.1169 | Val Loss: 1.3469 | Val OA: 72.13%
#
# Epoch 33 | alpha=0.200
# Train Loss: 1.1468 | Val Loss: 1.4222 | Val OA: 68.09%
#
# Epoch 34 | alpha=0.200
# Train Loss: 1.0876 | Val Loss: 1.3361 | Val OA: 74.42%
# Saved best model.
#
# Epoch 35 | alpha=0.200
# Train Loss: 1.0539 | Val Loss: 1.2550 | Val OA: 71.65%
# Saved best model.
#
# Epoch 36 | alpha=0.200
# Train Loss: 1.0575 | Val Loss: 1.3300 | Val OA: 71.78%
#
# Epoch 37 | alpha=0.200
# Train Loss: 1.0544 | Val Loss: 1.2932 | Val OA: 73.39%
#
# Epoch 38 | alpha=0.200
# Train Loss: 1.0123 | Val Loss: 1.2874 | Val OA: 74.88%
#
# Epoch 39 | alpha=0.200
# Train Loss: 1.0309 | Val Loss: 1.5713 | Val OA: 65.96%
#
# Epoch 40 | alpha=0.200
# Train Loss: 0.9729 | Val Loss: 1.1870 | Val OA: 73.48%
# Saved best model.
#
# Epoch 41 | alpha=0.200
# Train Loss: 0.9532 | Val Loss: 1.2877 | Val OA: 71.94%
#
# Epoch 42 | alpha=0.200
# Train Loss: 0.9800 | Val Loss: 1.1978 | Val OA: 74.93%
#
# Epoch 43 | alpha=0.200
# Train Loss: 0.9045 | Val Loss: 1.3101 | Val OA: 75.12%
#
# Epoch 44 | alpha=0.200
# Train Loss: 0.9013 | Val Loss: 1.2044 | Val OA: 75.24%
#
# Epoch 45 | alpha=0.200
# Train Loss: 0.8618 | Val Loss: 1.2369 | Val OA: 69.48%
#
# Epoch 46 | alpha=0.200
# Train Loss: 0.8922 | Val Loss: 1.2474 | Val OA: 74.28%
#
# Epoch 47 | alpha=0.200
# Train Loss: 0.9346 | Val Loss: 1.1088 | Val OA: 75.01%
# Saved best model.
#
# Epoch 48 | alpha=0.200
# Train Loss: 0.9249 | Val Loss: 1.2068 | Val OA: 74.72%
#
# Epoch 49 | alpha=0.200
# Train Loss: 0.8576 | Val Loss: 1.3003 | Val OA: 70.02%
#
# Epoch 50 | alpha=0.200
# Train Loss: 0.8560 | Val Loss: 1.2168 | Val OA: 72.22%
#
# Epoch 51 | alpha=0.200
# Train Loss: 0.7924 | Val Loss: 1.1109 | Val OA: 74.72%
#
# Epoch 52 | alpha=0.200
# Train Loss: 0.7645 | Val Loss: 1.1997 | Val OA: 74.22%
#
# Epoch 53 | alpha=0.200
# Train Loss: 0.7672 | Val Loss: 1.1944 | Val OA: 74.98%
#
# Epoch 54 | alpha=0.200
# Train Loss: 0.7727 | Val Loss: 1.1379 | Val OA: 75.32%
#
# Epoch 55 | alpha=0.200
# Train Loss: 0.7673 | Val Loss: 1.1248 | Val OA: 75.59%
#
# Epoch 56 | alpha=0.200
# Train Loss: 0.7046 | Val Loss: 1.1117 | Val OA: 77.31%
#
# Epoch 57 | alpha=0.200
# Train Loss: 0.7068 | Val Loss: 1.1755 | Val OA: 76.11%
#
# Epoch 58 | alpha=0.200
# Train Loss: 0.7325 | Val Loss: 1.1710 | Val OA: 73.40%
#
# Epoch 59 | alpha=0.200
# Train Loss: 0.6544 | Val Loss: 1.0398 | Val OA: 75.51%
# Saved best model.
#
# Epoch 60 | alpha=0.200
# Train Loss: 0.6332 | Val Loss: 1.0277 | Val OA: 78.15%
# Saved best model.
#
# Epoch 61 | alpha=0.200
# Train Loss: 0.6133 | Val Loss: 1.0859 | Val OA: 77.17%
#
# Epoch 62 | alpha=0.200
# Train Loss: 0.5865 | Val Loss: 0.9938 | Val OA: 77.77%
# Saved best model.
#
# Epoch 63 | alpha=0.200
# Train Loss: 0.5877 | Val Loss: 1.1893 | Val OA: 75.75%
#
# Epoch 64 | alpha=0.200
# Train Loss: 0.5687 | Val Loss: 0.9694 | Val OA: 80.33%
# Saved best model.
#
# Epoch 65 | alpha=0.200
# Train Loss: 0.5337 | Val Loss: 1.1216 | Val OA: 78.42%
#
# Epoch 66 | alpha=0.200
# Train Loss: 0.4910 | Val Loss: 1.0850 | Val OA: 78.98%
#
# Epoch 67 | alpha=0.200
# Train Loss: 0.5102 | Val Loss: 1.0943 | Val OA: 78.16%
#
# Epoch 68 | alpha=0.200
# Train Loss: 0.5161 | Val Loss: 1.3252 | Val OA: 78.78%
#
# Epoch 69 | alpha=0.200
# Train Loss: 0.6504 | Val Loss: 1.7523 | Val OA: 68.28%
#
# Epoch 70 | alpha=0.200
# Train Loss: 0.7999 | Val Loss: 1.1865 | Val OA: 77.01%
#
# Epoch 71 | alpha=0.200
# Train Loss: 0.5454 | Val Loss: 1.0911 | Val OA: 77.26%
#
# Epoch 72 | alpha=0.200
# Train Loss: 0.4769 | Val Loss: 1.2214 | Val OA: 75.51%
#
# Epoch 73 | alpha=0.200
# Train Loss: 0.5197 | Val Loss: 1.2139 | Val OA: 79.05%
#
# Epoch 74 | alpha=0.200
# Train Loss: 0.4421 | Val Loss: 1.0924 | Val OA: 81.80%
#
# Epoch 75 | alpha=0.200
# Train Loss: 0.4336 | Val Loss: 1.0678 | Val OA: 81.29%
#
# Epoch 76 | alpha=0.200
# Train Loss: 0.4470 | Val Loss: 1.1446 | Val OA: 80.28%
#
# Epoch 77 | alpha=0.200
# Train Loss: 0.5625 | Val Loss: 1.1975 | Val OA: 74.33%
#
# Epoch 78 | alpha=0.200
# Train Loss: 0.4665 | Val Loss: 1.1489 | Val OA: 77.81%
#
# Epoch 79 | alpha=0.200
# Train Loss: 0.4500 | Val Loss: 1.1567 | Val OA: 80.94%
#
# Epoch 80 | alpha=0.200
# Train Loss: 0.4093 | Val Loss: 1.0885 | Val OA: 79.28%
#
# Epoch 81 | alpha=0.200
# Train Loss: 0.3666 | Val Loss: 1.0744 | Val OA: 81.72%
#
# Epoch 82 | alpha=0.200
# Train Loss: 0.4130 | Val Loss: 1.0550 | Val OA: 80.81%
#
# Epoch 83 | alpha=0.200
# Train Loss: 0.3966 | Val Loss: 1.1705 | Val OA: 82.69%
#
# Epoch 84 | alpha=0.200
# Train Loss: 0.3476 | Val Loss: 1.1286 | Val OA: 82.65%
#
# Epoch 85 | alpha=0.200
# Train Loss: 0.3464 | Val Loss: 1.4571 | Val OA: 75.61%
#
# Epoch 86 | alpha=0.200
# Train Loss: 0.4684 | Val Loss: 1.1467 | Val OA: 80.45%
#
# Epoch 87 | alpha=0.200
# Train Loss: 0.3517 | Val Loss: 1.0245 | Val OA: 82.16%
#
# Epoch 88 | alpha=0.200
# Train Loss: 0.2980 | Val Loss: 1.0898 | Val OA: 82.82%
#
# Epoch 89 | alpha=0.200
# Train Loss: 0.2814 | Val Loss: 1.1331 | Val OA: 82.02%
#
# Epoch 90 | alpha=0.200
# Train Loss: 0.3226 | Val Loss: 1.1871 | Val OA: 79.10%
#
# Epoch 91 | alpha=0.200
# Train Loss: 0.2817 | Val Loss: 1.0718 | Val OA: 82.45%
#
# Epoch 92 | alpha=0.200
# Train Loss: 0.2350 | Val Loss: 1.0641 | Val OA: 83.51%
#
# Epoch 93 | alpha=0.200
# Train Loss: 0.2144 | Val Loss: 1.0333 | Val OA: 83.51%
#
# Epoch 94 | alpha=0.200
# Train Loss: 0.2044 | Val Loss: 1.1624 | Val OA: 83.16%
#
# Epoch 95 | alpha=0.200
# Train Loss: 0.1922 | Val Loss: 1.1948 | Val OA: 83.42%
#
# Epoch 96 | alpha=0.200
# Train Loss: 0.1838 | Val Loss: 1.2728 | Val OA: 84.21%
#
# Epoch 97 | alpha=0.200
# Train Loss: 0.1810 | Val Loss: 1.2543 | Val OA: 83.48%
#
# Epoch 98 | alpha=0.200
# Train Loss: 0.1768 | Val Loss: 1.1214 | Val OA: 84.26%
#
# Epoch 99 | alpha=0.200
# Train Loss: 0.1606 | Val Loss: 1.2762 | Val OA: 83.83%
#
# Epoch 100 | alpha=0.200
# Train Loss: 0.1529 | Val Loss: 1.0739 | Val OA: 83.85%
#
# Test Loss: 2.5173 | Test OA: 78.16%
# OA: 78.16%, AA: 37.77%, Kappa: 0.7427, mIoU: 0.2928
